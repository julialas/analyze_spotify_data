# %% [markdown]
# # More Visualization Types

# %%
# importing the libraries for data processing
import numpy as np 
import pandas as pd 

#These two modules will be used to create some basic visualizations
import seaborn as sns
import matplotlib.pyplot as plt

#This is a jupyter magic command that embeds the image generated by matplotlib right after the code cell
# %matplotlib inline

# %%
#open merged dataset
df_streams = pd.read_csv('data/merged_chart_tracks.csv')
df_streams.head()
# Out:
#          date  position            track_name            artist  streams  \
# 0  2017-01-01         1  Versace on the Floor        Bruno Mars   185236
# 1  2017-01-01         2  Say You Won't Let Go      James Arthur   180552
# 2  2017-01-01         3                Closer  The Chainsmokers   158720
# 3  2017-01-01         4           All We Know  The Chainsmokers   130874
# 4  2017-01-01         5      Don't Wanna Know          Maroon 5   129656
#
#                  track_id               artist_id                album_id  \
# 0  0kN8xEmgMW9mh7UmDYHlJP  0du5cEVh5yTK9QJze8zA0C  4PgleR09JVnm3zY1fW3XBA
# 1  5uCax9HTNlzGybIStD3vDh  4IWBUUAFIplrNtaOHcJPRM  7oiJYvEJHsmYtrgviAVIBD
# 2  7BKLCZ1jbUBVqRi2FVlTVw  69GGBxA162lTqCwzJG5jLp  0rSLgV8p5FzfnqlEk4GzxE
# 3  2rizacJSyD9S1IQUxUxnsK  69GGBxA162lTqCwzJG5jLp  0xmaV6EtJ4M3ebZUPRnhyb
# 4  5MFzQMkrl1FOOng9tq6R9r  04gDigrS5kc9YWfZHwBETP  0fvTn3WXF39kQs9i3bnNpP
#
#    duration release_date  ...  speechiness  acousticness  instrumentalness  \
# 0    261240   2016-11-17  ...       0.0454         0.196           0.00000
# 1    211466   2016-10-28  ...       0.0590         0.695           0.00000
# 2    244960   2016-07-29  ...       0.0338         0.414           0.00000
# 3    194080   2016-09-29  ...       0.0307         0.097           0.00272
# 4    214480   2016-10-11  ...       0.0800         0.338           0.00000
#
#    liveness  valence    tempo  duration_mins  release_year  release_month  \
# 0    0.0830    0.301  174.152       4.354000        2016.0           11.0
# 1    0.0902    0.494   85.043       3.524433        2016.0           10.0
# 2    0.1110    0.661   95.010       4.082667        2016.0            7.0
# 3    0.1150    0.296   90.000       3.234667        2016.0            9.0
# 4    0.0975    0.447  100.048       3.574667        2016.0           10.0
#
#    release_day
# 0         17.0
# 1         28.0
# 2         29.0
# 3         29.0
# 4         11.0
#
# [5 rows x 26 columns]

# %%
#transform date column into a datetime column
df_streams['date'] = pd.to_datetime(df_streams['date'])
df_streams = df_streams.set_index('date')
df_streams.head()
# Out:
#             position            track_name            artist  streams  \
# date
# 2017-01-01         1  Versace on the Floor        Bruno Mars   185236
# 2017-01-01         2  Say You Won't Let Go      James Arthur   180552
# 2017-01-01         3                Closer  The Chainsmokers   158720
# 2017-01-01         4           All We Know  The Chainsmokers   130874
# 2017-01-01         5      Don't Wanna Know          Maroon 5   129656
#
#                           track_id               artist_id  \
# date
# 2017-01-01  0kN8xEmgMW9mh7UmDYHlJP  0du5cEVh5yTK9QJze8zA0C
# 2017-01-01  5uCax9HTNlzGybIStD3vDh  4IWBUUAFIplrNtaOHcJPRM
# 2017-01-01  7BKLCZ1jbUBVqRi2FVlTVw  69GGBxA162lTqCwzJG5jLp
# 2017-01-01  2rizacJSyD9S1IQUxUxnsK  69GGBxA162lTqCwzJG5jLp
# 2017-01-01  5MFzQMkrl1FOOng9tq6R9r  04gDigrS5kc9YWfZHwBETP
#
#                           album_id  duration release_date  popularity  ...  \
# date                                                                   ...
# 2017-01-01  4PgleR09JVnm3zY1fW3XBA    261240   2016-11-17          75  ...
# 2017-01-01  7oiJYvEJHsmYtrgviAVIBD    211466   2016-10-28          85  ...
# 2017-01-01  0rSLgV8p5FzfnqlEk4GzxE    244960   2016-07-29          84  ...
# 2017-01-01  0xmaV6EtJ4M3ebZUPRnhyb    194080   2016-09-29          69  ...
# 2017-01-01  0fvTn3WXF39kQs9i3bnNpP    214480   2016-10-11          14  ...
#
#             speechiness  acousticness  instrumentalness  liveness  valence  \
# date
# 2017-01-01       0.0454         0.196           0.00000    0.0830    0.301
# 2017-01-01       0.0590         0.695           0.00000    0.0902    0.494
# 2017-01-01       0.0338         0.414           0.00000    0.1110    0.661
# 2017-01-01       0.0307         0.097           0.00272    0.1150    0.296
# 2017-01-01       0.0800         0.338           0.00000    0.0975    0.447
#
#               tempo  duration_mins  release_year  release_month  release_day
# date
# 2017-01-01  174.152       4.354000        2016.0           11.0         17.0
# 2017-01-01   85.043       3.524433        2016.0           10.0         28.0
# 2017-01-01   95.010       4.082667        2016.0            7.0         29.0
# 2017-01-01   90.000       3.234667        2016.0            9.0         29.0
# 2017-01-01  100.048       3.574667        2016.0           10.0         11.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 1. Histograms
#
# Put simply, histograms are graphical representation of tallies.
# Read more about histograms here: (https://statistics.laerd.com/statistical-guides/understanding-histograms.php).
#
# These are very useful in EDA because at a glance, you could already see how the data is spread over its range.
#
# In particular, you should look out for:
# 1. Skewness - Do the values peak around the mean, or over lower (left-skewed)/higher values(right-skewed)?
# 2. Mode - Does it have one peak (unimodal)? two peaks (bimodal)? How many peaks?
# 3. Outliers - Are there a few data points that are substantially distant from bulk of all values?
#
# It is strongly advised that you look at histograms before you do any aggregations.

# %% [markdown]
# **Q**: Compare the positions earned by Ariana Grande, Dua Lipa and Lady Gaga Songs in 2019

# %%
plt.hist?

# %%
plt.figure(figsize=(8,6))    
ax = plt.subplot(111) 

for artist_name in ["Ariana Grande", "Dua Lipa" , "Lady Gaga"]:
    data = df_streams[(df_streams['artist']==artist_name)].loc['2019-01-01':'2019-12-31']
    plt.hist(data['position'].values,bins=np.arange(0,210,10),\
             histtype='stepfilled', label=artist_name, alpha=0.35)
    
plt.xticks([1]+np.arange(0,210,10).tolist())
plt.xlim([200,1]) 

plt.ylabel('Frequency')
plt.xlabel('Position')
plt.legend(frameon=False)

# %% [markdown]
# ### Scatter plot
# A scatter plot visualizes the spread of a dataset in 2 dimensions. A scatter plot with point size as a variable is called a bubble chart

# %% [markdown]
# Q: How do Ariana Grande's top 5 streamed songs compare with Dua Lipa  top 5 streamed songs in terms of danceability and total number of streams

# %%
df_ariana = df_streams[df_streams['artist']=='Ariana Grande']\
                                .groupby(['track_name'])\
                                .agg({'streams':np.sum,'danceability':np.mean})\
                                .reset_index()\
                                .sort_values('streams',ascending=False)[:5]
df_dua = df_streams[df_streams['artist']=='Dua Lipa']\
                                .groupby(['track_name'])\
                                .agg({'streams':np.sum,'danceability':np.mean})\
                                .reset_index()\
                                .sort_values('streams',ascending=False)[:5]

# %%
plt.figure(figsize=(6,5))    
ax = plt.subplot(111) 

df_dua.plot(x='danceability', y='streams', kind='scatter', color='C0', s=50,
            label='Ariana Grande', ax=ax)
df_ariana.plot(x='danceability', y='streams', kind='scatter',color='C1',s=50,
               label='Dua Lipa', ax=ax)

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.10), frameon=False,ncol=3)

# %% [markdown]
# Q: Could you put annotations of the song names on each circle? How would you improve this plot?

# %% [markdown]
# ### 2. Stacked Bar/Area chart
#
# A stacked bar/area chart shows the extent of contribution of one/few parts to the whole.
# It is advised that the total is divided to 2-3 major contributing parts only--lump all else in another category ("others")

# %% [markdown]
# **Q**: How many streams did the songs from Ed Sheeran's 2 latest albums *No 6 collaboration project* (album id: 3oIFxDIo2fwuk4lwCmFZCx) and *Divide* (album id: 3T4tUhGYeRNVUGevb0wThu) contribute to his monthly total streams in 2019?

# %%
df_ed = df_streams[df_streams['artist']=='Ed Sheeran'].loc['2019-01-01':'2019-12-31']\
                                .groupby(['album_id'])['streams']\
                                .resample('M').sum().reset_index()\
                                .sort_values('streams',ascending=False)
#df_ed = df_ed.set_index('date')
df_ed['album_name']= df_ed['album_id'].apply(lambda x: 
                                             'No.6' if (x=='3oIFxDIo2fwuk4lwCmFZCx') else 
                                            'Divide' if (x=='3T4tUhGYeRNVUGevb0wThu') else 'others')

df_ed = df_ed.set_index('date')
df_ed = df_ed.groupby(['album_name'])['streams']\
                                .resample('M').sum().reset_index()\
                                .sort_values('streams',ascending=False)
df_ed
# Out:
#    album_name       date   streams
# 12       No.6 2019-07-31  13430215
# 13       No.6 2019-08-31  13297015
# 14       No.6 2019-09-30  10789816
# 15       No.6 2019-10-31  10632380
# 16       No.6 2019-11-30   8937603
# 23     others 2019-06-30   8853893
# 17       No.6 2019-12-31   8566836
# 24     others 2019-07-31   6596477
# 22     others 2019-05-31   5430792
# 0      Divide 2019-01-31   2728889
# 2      Divide 2019-03-31   2205462
# 4      Divide 2019-05-31   2195225
# 1      Divide 2019-02-28   2187368
# 3      Divide 2019-04-30   2093779
# 6      Divide 2019-07-31   2060638
# 5      Divide 2019-06-30   1940418
# 7      Divide 2019-08-31   1822953
# 8      Divide 2019-09-30   1755058
# 9      Divide 2019-10-31   1713192
# 18     others 2019-01-31   1573968
# 10     Divide 2019-11-30   1552979
# 11     Divide 2019-12-31    939277
# 20     others 2019-03-31    914278
# 25     others 2019-08-31    897813
# 27     others 2019-10-31    885144
# 26     others 2019-09-30    859249
# 21     others 2019-04-30    850067
# 19     others 2019-02-28    839896
# 28     others 2019-11-30    815945
# 29     others 2019-12-31    753779

# %%
df_ed.pivot(index='date',columns='album_name',values='streams')
# Out:
# album_name     Divide        No.6     others
# date
# 2019-01-31  2728889.0         NaN  1573968.0
# 2019-02-28  2187368.0         NaN   839896.0
# 2019-03-31  2205462.0         NaN   914278.0
# 2019-04-30  2093779.0         NaN   850067.0
# 2019-05-31  2195225.0         NaN  5430792.0
# 2019-06-30  1940418.0         NaN  8853893.0
# 2019-07-31  2060638.0  13430215.0  6596477.0
# 2019-08-31  1822953.0  13297015.0   897813.0
# 2019-09-30  1755058.0  10789816.0   859249.0
# 2019-10-31  1713192.0  10632380.0   885144.0
# 2019-11-30  1552979.0   8937603.0   815945.0
# 2019-12-31   939277.0   8566836.0   753779.0

# %%
plt.figure(figsize=(8,6))    
ax = plt.subplot(111) 

color_list = ['skyblue','C7','0.8']
#reshape
data = df_ed.pivot(index='date',columns='album_name',values='streams')#/1000000
data.plot.area(ax=ax, lw=0, colors=color_list)


#plt.yticks(np.arange(0,25,5),[str(x)+'M' if x>0 else str(x) for x in np.arange(0,25,5)])
plt.ylabel('streams')

plt.xlabel('')
plt.legend(frameon=False)
# Out:
# C:\miniconda\envs\workspace\lib\site-packages\pandas\plotting\_matplotlib\core.py:203: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   "'colors' is being deprecated. Please use 'color'"

# %%
plt.figure(figsize=(8,6))    
ax = plt.subplot(111) 

color_list = ['skyblue','C7','0.8']
#reshape
data = df_ed.pivot(index='date',columns='album_name',values='streams')
#normalize with monthly sums
data[data.columns] = 100*data[data.columns].div(data.sum(axis=1), axis=0)
#plot
data.plot.area(ax=ax, lw=0, colors=color_list)

#custom ticks
plt.yticks(np.arange(0,120,20),[str(x)+'%' for x in np.arange(0,120,20)])
plt.ylabel('streams')

plt.ylim([0,100])

plt.xlabel('')

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), frameon=False,ncol=3)

# %% [markdown]
# ### 3. Boxplot
#
# Box plots are useful as they provide a visual summary of the data to quickly identify mean values, the dispersion of the data set, and signs of skewness.
#
# Here are the parts of a box plot
# ![](https://www.simplypsychology.org/boxplot.jpg?ezimgfmt=rs:279x143/rscb18/ng:webp/ngcb18)

# %% [markdown]
# **Q**: How does loudness, tempo, danceability, energy, and valence of KPOP girl group songs compare with the rest of the dataset?

# %%
kpop_girl_grps = ["BLACKPINK","Girls' Generation-Oh!GG", "Girls' Generation-TTS",\
                  "ITZY","IZ*ONE","MOMOLAND","Red Velvet","TWICE"]
metrics = ["loudness", "tempo", "danceability", "energy","valence"]

# %%
df_metrics = df_streams.groupby(['track_name','artist'])[metrics].mean().reset_index()

df_metrics['is_gg']= ['kpop girl group' if artist in kpop_girl_grps else 'all else'\
                      for artist in df_metrics['artist'].values]

#get max value for normalization
max_tempo = df_metrics['tempo'].max()
min_loudness = df_metrics['loudness'].min()

#normalize tempo and loudness
df_metrics['tempo']= df_metrics['tempo']/max_tempo
df_metrics['loudness']= df_metrics['loudness']/min_loudness

#set multiindex
df_metrics = df_metrics.set_index(['track_name','artist','is_gg'])

#stack to achieve shape demanded by boxplot
df_metrics = pd.DataFrame({'value':df_metrics.stack()})
df_metrics = df_metrics.reset_index()

df_metrics = df_metrics.rename(columns={'level_3':'metric'})
df_metrics.head()
# Out:
#   track_name              artist     is_gg        metric     value
# 0  'Di Lahat  Donnalyn Bartolome  all else      loudness  0.306289
# 1  'Di Lahat  Donnalyn Bartolome  all else         tempo  0.453103
# 2  'Di Lahat  Donnalyn Bartolome  all else  danceability  0.686000
# 3  'Di Lahat  Donnalyn Bartolome  all else        energy  0.731000
# 4  'Di Lahat  Donnalyn Bartolome  all else       valence  0.433000

# %%
plt.figure(figsize=(8,6))    
ax = plt.subplot(111) 
#data.boxplot(column=['SepalLength'], by='Name', ax=ax)
sns.boxplot(data = df_metrics, x ='metric', y='value',  hue='is_gg', ax=ax,
            hue_order=['kpop girl group','all else'], palette=['pink','C7'])

ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), frameon=False,ncol=3)

# %% [markdown]
# ### 4. Heatmap
# The heatmap is a way of representing the data in a 2-dimensional form. The data values are represented as colors in the graph. The goal of the heatmap is to provide a colored visual summary of information.

# %% [markdown]
# **Q**: Visualize Ben&Ben songs in top 200 as a heatmap of its monthly streams

# %%
df_bb = df_streams[df_streams['artist']=="Ben&Ben"].groupby('track_name')[['streams']]\
                                                                .resample('M').sum()
df_bb = df_bb.reset_index()
df_bb = df_bb[df_bb['date']<='2020-03-31']
#clean long titles
df_bb['track_name'] = df_bb['track_name'].apply(lambda x: x.split('(')[0])\
                                        .apply(lambda x: x.split(' - ')[0])
df_bb
# Out:
#     track_name       date  streams
# 0    Araw-Araw 2019-05-31    98063
# 1    Araw-Araw 2019-06-30        0
# 2    Araw-Araw 2019-07-31        0
# 3    Araw-Araw 2019-08-31        0
# 4    Araw-Araw 2019-09-30   742222
# ..         ...        ...      ...
# 211      Susi  2018-09-30   586438
# 212      Susi  2018-10-31  1471573
# 213      Susi  2018-11-30   446932
# 214      Susi  2018-12-31    21139
# 215        War 2020-03-31    40905
#
# [206 rows x 3 columns]

# %%
arr_df = df_bb.pivot(index='track_name', columns='date',values='streams')
arr_df = arr_df/1000000
arr_df.fillna(0, inplace=True)
arr_df['total_streams'] = arr_df.sum(axis=1)
arr_df = arr_df.sort_values('total_streams',ascending=False)

# %%
plt.figure(figsize=(8,6))    
ax = plt.subplot(111) 

#get index and specify format
moncols=arr_df.columns[:-1]
yymm_cols = pd.Series(moncols.values).apply(lambda x: x.strftime('%Y-%m'))

sns.heatmap(arr_df[moncols],ax=ax,
            cmap='viridis',
            cbar_kws={'label': 'million streams', 'ticks':np.arange(0,10,2) },
            xticklabels=yymm_cols, yticklabels=True)

plt.ylabel('')
plt.xlabel('')
# Out:
# Text(0.5, 33.0, '')

# %% [markdown]
# **Q**: Visualize Jose Mari Chan songs as a heatmap of its monthly streams

# %%
df_jmc = df_streams[df_streams['artist']=="Jose Mari Chan"].groupby('track_name')[['streams']]\
                                                                .resample('M').sum()
df_jmc = df_jmc.reset_index()
df_jmc = df_jmc[df_jmc['date']<='2020-03-31']
#clean long titles
df_jmc['track_name'] = df_jmc['track_name'].apply(lambda x: x.split('(')[0])\
                                        .apply(lambda x: x.split(' - ')[0])
df_jmc
# Out:
#                   track_name       date  streams
# 0   A Christmas Song for You 2017-12-31    22993
# 1        A Perfect Christmas 2019-09-30    28344
# 2        A Perfect Christmas 2019-10-31        0
# 3        A Perfect Christmas 2019-11-30        0
# 4        A Perfect Christmas 2019-12-31    66892
# 5    Christmas in Our Hearts 2017-12-31   334582
# 6    Christmas in Our Hearts 2018-01-31        0
# 7    Christmas in Our Hearts 2018-02-28        0
# 8    Christmas in Our Hearts 2018-03-31        0
# 9    Christmas in Our Hearts 2018-04-30        0
# 10   Christmas in Our Hearts 2018-05-31        0
# 11   Christmas in Our Hearts 2018-06-30        0
# 12   Christmas in Our Hearts 2018-07-31        0
# 13   Christmas in Our Hearts 2018-08-31        0
# 14   Christmas in Our Hearts 2018-09-30   181357
# 15   Christmas in Our Hearts 2018-10-31        0
# 16   Christmas in Our Hearts 2018-11-30        0
# 17   Christmas in Our Hearts 2018-12-31   326951
# 18   Christmas in Our Hearts 2019-01-31        0
# 19   Christmas in Our Hearts 2019-02-28        0
# 20   Christmas in Our Hearts 2019-03-31        0
# 21   Christmas in Our Hearts 2019-04-30        0
# 22   Christmas in Our Hearts 2019-05-31        0
# 23   Christmas in Our Hearts 2019-06-30        0
# 24   Christmas in Our Hearts 2019-07-31        0
# 25   Christmas in Our Hearts 2019-08-31    32323
# 26   Christmas in Our Hearts 2019-09-30   136130
# 27   Christmas in Our Hearts 2019-10-31        0
# 28   Christmas in Our Hearts 2019-11-30        0
# 29   Christmas in Our Hearts 2019-12-31   417142
# 30          Mary's Boy Child 2017-12-31    35123
# 31          Mary's Boy Child 2018-01-31        0
# 32          Mary's Boy Child 2018-02-28        0
# 33          Mary's Boy Child 2018-03-31        0
# 34          Mary's Boy Child 2018-04-30        0
# 35          Mary's Boy Child 2018-05-31        0
# 36          Mary's Boy Child 2018-06-30        0
# 37          Mary's Boy Child 2018-07-31        0
# 38          Mary's Boy Child 2018-08-31        0
# 39          Mary's Boy Child 2018-09-30        0
# 40          Mary's Boy Child 2018-10-31        0
# 41          Mary's Boy Child 2018-11-30        0
# 42          Mary's Boy Child 2018-12-31    33756
# 43          Mary's Boy Child 2019-01-31        0
# 44          Mary's Boy Child 2019-02-28        0
# 45          Mary's Boy Child 2019-03-31        0
# 46          Mary's Boy Child 2019-04-30        0
# 47          Mary's Boy Child 2019-05-31        0
# 48          Mary's Boy Child 2019-06-30        0
# 49          Mary's Boy Child 2019-07-31        0
# 50          Mary's Boy Child 2019-08-31        0
# 51          Mary's Boy Child 2019-09-30        0
# 52          Mary's Boy Child 2019-10-31        0
# 53          Mary's Boy Child 2019-11-30        0
# 54          Mary's Boy Child 2019-12-31    42367

# %%
arr_df = df_jmc.pivot(index='track_name', columns='date',values='streams')
arr_df = arr_df/100000
arr_df.fillna(0, inplace=True)
arr_df['total_streams'] = arr_df.sum(axis=1)
arr_df = arr_df.sort_values('total_streams',ascending=False)

# %%
plt.figure(figsize=(8,6))    
ax = plt.subplot(111) 

#get index and specify format
moncols=arr_df.columns[:-1]
yymm_cols = pd.Series(moncols.values).apply(lambda x: x.strftime('%Y-%m'))

sns.heatmap(arr_df[moncols],ax=ax,
            cmap='viridis',
            cbar_kws={'label': 'streams x 100000' },
            xticklabels=yymm_cols, yticklabels=True)

plt.ylabel('')
plt.xlabel('')
# Out:
# Text(0.5, 33.0, '')
